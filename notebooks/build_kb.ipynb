# %% [markdown]
# # Imports

# %%
# %pip install -q hf_transfer
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 75.4 MB/s eta 0:00:00:00:01
# Note: you may need to restart the kernel to use updated packages.

# %%
from kaggle_secrets import UserSecretsClient
from huggingface_hub import login
import os

user_secrets = UserSecretsClient()
token = user_secrets.get_secret("GITHUB_VIETTEL")

hf_token = user_secrets.get_secret("HF_TOKEN")
os.environ["HF_HUB_ENABLE_HF_TRANSFER"] = "1"

# %%
os.environ["GITHUB_TOKEN"] = token

# !git clone https://oauth2:$GITHUB_TOKEN@github.com/KangaOnGit/Ontological-Reasoning-in-Medical-Knowledge-Retrieval.git
# Out:
# Cloning into 'Ontological-Reasoning-in-Medical-Knowledge-Retrieval'...
# remote: Enumerating objects: 292, done.
# remote: Counting objects: 100% (292/292), done.
# remote: Compressing objects: 100% (240/240), done.
# remote: Total 292 (delta 56), reused 273 (delta 40), pack-reused 0 (from 0)
# Receiving objects: 100% (292/292), 8.03 MiB | 19.12 MiB/s, done.
# Resolving deltas: 100% (56/56), done.

# %%
cd Ontological-Reasoning-in-Medical-Knowledge-Retrieval
# Out:
# /kaggle/working/Ontological-Reasoning-in-Medical-Knowledge-Retrieval

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.5/18.5 MB 71.9 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 MB 46.8 MB/s eta 0:00:00:00:0100:01
# ...
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 24.0.0
#     Uninstalling pyarrow-24.0.0:
#       Successfully uninstalled pyarrow-24.0.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.39.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# google-adk 1.29.0 requires google-cloud-bigquery-storage>=2.0.0, which is not installed.
# datasets 5.0.0 requires pyarrow>=21.0.0, but you have pyarrow 16.1.0 which is incompatible.
# ...

# %%
# !pip install -e .
# Out:
# Obtaining file:///kaggle/working/Ontological-Reasoning-in-Medical-Knowledge-Retrieval
# ERROR: file:///kaggle/working/Ontological-Reasoning-in-Medical-Knowledge-Retrieval does not appear to be a Python project: neither 'setup.py' nor 'pyproject.toml' found.

# %%
# !python -m scripts.build_knowledge_base.build_index
# Out:
# 2026-07-28 11:55:59,222 INFO src.rag.knowledge_base.text_encoder: Loading model cambridgeltl/SapBERT-UMLS-2020AB-all-lang-from-XLMR on cuda
# 2026-07-28 11:55:59,321 INFO httpx: HTTP Request: HEAD https://huggingface.co/cambridgeltl/SapBERT-UMLS-2020AB-all-lang-from-XLMR/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# ...
# 2026-07-28 11:55:59,322 WARNING huggingface_hub.utils._http: Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 2026-07-28 11:55:59,328 INFO httpx: HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/cambridgeltl/SapBERT-UMLS-2020AB-all-lang-from-XLMR/47b6bd041ba61311584bb2494edfda5c7d9b719f/config.json "HTTP/1.1 200 OK"
# 2026-07-28 11:55:59,336 INFO httpx: HTTP Request: GET https://huggingface.co/api/resolve-cache/models/cambridgeltl/SapBERT-UMLS-2020AB-all-lang-from-XLMR/47b6bd041ba61311584bb2494edfda5c7d9b719f/config.json "HTTP/1.1 200 OK"
# ...
